# %%
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.cross_validation import cross_val_score
from sklearn.grid_search import GridSearchCV
import numpy as np
from sklearn.cross_validation import train_test_split, cross_val_score

# %%
np_lst = pd.read_csv('np_lst.txt', header=None)[0].values

# %%
np_lst
# Out:
# array(['biking_a.npy', 'biking_b.npy', 'cooking_a.npy', 'cooking_b.npy',
#        'fashion_a.npy', 'fashion_b.npy', 'fitness_a.npy', 'fitness_b.npy',
#        'gardening_a.npy', 'gardening_b.npy', 'hiking_a.npy',
#        'hiking_b.npy', 'hunting_fishing_a.npy', 'hunting_fishing_b.npy',
#        'kids_a.npy', 'kids_b.npy', 'pets_a.npy', 'pets_b.npy',
#        'social_out_a.npy', 'social_out_b.npy', 'summer_fun_a.npy',
#        'summer_fun_b.npy', 'winter_sports_a.npy', 'winter_sports_b.npy'], dtype=object)

# %%
np_path = '../numpiis/'
feat_array = []
for i, feats in enumerate(np_lst):
    if '_a' in feats:
        feat_array.append(np.load(np_path+feats))
    else:
        feat_array[-1] = np.vstack([feat_array[-1], np.load(np_path+feats)])

# %%
len(feat_array[0])
# Out:
# 1097

# %%
label_lst = []
for i, feats in enumerate(feat_array):
    label_lst.append(i*np.ones(len(feats)))

labels = np.hstack(label_lst)

# %%
features = np.vstack(feat_array)

# %%
features.shape
# Out:
# (14454, 4096)

# %%
labels.shape
# Out:
# (14454,)

# %%
X = features
y = labels

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.8)

# %%
mod_logit = LogisticRegression()

# %%
score_lst = []
score_lst.append(cross_val_score(mod_logit, X, y))
print np.array(score_lst).mean()
# Out:
# 0.738338062202

# %%
mod_RF = RandomForestClassifier(n_estimators=200)

# %%
score_lst = []
score_lst.append(cross_val_score(mod_RF, X, y))
print np.array(score_lst).mean()
# Out:
# 0.722909874312

# %%
mod_svm = SVC(kernel='linear')

# %%
score_lst = []
score_lst.append(cross_val_score(mod_svm, X, y))
print np.array(score_lst).mean()
# Out:
# 0.752865007745

# %%
mod_gbc = GradientBoostingClassifier()

# %%
score_lst = []
score_lst.append(cross_val_score(mod_gbc, X, y))
print np.array(score_lst).mean()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-60-d5291d4c8dfb> in <module>()
#       1 score_lst = []
# ----> 2 score_lst.append(cross_val_score(mod_gbc, X, y))
#       3 print np.array(score_lst).mean()
#
# /Users/will/anaconda/lib/python2.7/site-packages/sklearn/cross_validation.pyc in cross_val_score(estimator, X, y, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch)
#    1359                                               train, test, verbose, None,
#    1360                                               fit_params)
# -> 1361                       for train, test in cv)
#    1362     return np.array(scores)[:, 0]
#    1363
#
# /Users/will/anaconda/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.pyc in __call__(self, iterable)
#     657             self._iterating = True
#     658             for function, args, kwargs in iterable:
# --> 659                 self.dispatch(function, args, kwargs)
#     660
#     661             if pre_dispatch == "all" or n_jobs == 1:
#
# /Users/will/anaconda/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.pyc in dispatch(self, func, args, kwargs)
#     404         """
#     405         if self._pool is None:
# --> 406             job = ImmediateApply(func, args, kwargs)
#     407             index = len(self._jobs)
#     408             if not _verbosity_filter(index, self.verbose):
#
# /Users/will/anaconda/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.pyc in __init__(self, func, args, kwargs)
#     138         # Don't delay the application, to avoid keeping the input
#     139         # arguments in memory
# --> 140         self.results = func(*args, **kwargs)
#     141
#     142     def get(self):
#
# /Users/will/anaconda/lib/python2.7/site-packages/sklearn/cross_validation.pyc in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, error_score)
#    1457             estimator.fit(X_train, **fit_params)
#    1458         else:
# -> 1459             estimator.fit(X_train, y_train, **fit_params)
#    1460
#    1461     except Exception as e:
#
# /Users/will/anaconda/lib/python2.7/site-packages/sklearn/ensemble/gradient_boosting.pyc in fit(self, X, y, sample_weight, monitor)
#     978         # fit the boosting stages
#     979         n_stages = self._fit_stages(X, y, y_pred, sample_weight, random_state,
# --> 980                                     begin_at_stage, monitor)
#     981         # change shape of arrays after fit (early-stopping or additional ests)
#     982         if n_stages != self.estimators_.shape[0]:
#
# /Users/will/anaconda/lib/python2.7/site-packages/sklearn/ensemble/gradient_boosting.pyc in _fit_stages(self, X, y, y_pred, sample_weight, random_state, begin_at_stage, monitor)
#    1038             y_pred = self._fit_stage(i, X, y, y_pred, sample_weight,
#    1039                                      sample_mask, criterion, splitter,
# -> 1040                                      random_state)
#    1041
#    1042             # track deviance (= loss)
#
# /Users/will/anaconda/lib/python2.7/site-packages/sklearn/ensemble/gradient_boosting.pyc in _fit_stage(self, i, X, y, y_pred, sample_weight, sample_mask, criterion, splitter, random_state)
#     764
#     765             tree.fit(X, residual, sample_weight=sample_weight,
# --> 766                      check_input=False)
#     767
#     768             # update tree leaves
#
# /Users/will/anaconda/lib/python2.7/site-packages/sklearn/tree/tree.pyc in fit(self, X, y, sample_weight, check_input)
#     302                                            max_leaf_nodes)
#     303
# --> 304         builder.build(self.tree_, X, y, sample_weight)
#     305
#     306         if self.n_outputs_ == 1:
#
# KeyboardInterrupt:

# %%
score_lst = []
score_lst.append(cross_val_score(mod_logit, X, y,scoring='mean_squared_error') )
print np.array(score_lst).mean()
# Out:
# -5.69939780715

# %%
score_lst = []
score_lst.append(cross_val_score(mod_svm, X, y,scoring='mean_squared_error') )
print np.array(score_lst).mean()
# Out:
# -5.58323709763
